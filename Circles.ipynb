# %%
from sklearn import svm
svm.SVC?

# %%
from sklearn import datasets
ds = datasets.make_circles()

X = ds[0]
y = ds[1]

from sklearn import svm
c = svm.SVC(kernel="rbf")

c.fit(X,y)

from plot import plot_decision_regions
# %matplotlib inline

plot_decision_regions(X,y,c)

# %%
from sklearn import datasets
ds = datasets.make_moons(n_samples=500)

X = ds[0]
y = ds[1]

from sklearn import svm
c = svm.SVC()

c.fit(X,y)

from plot import plot_decision_regions
# %matplotlib inline

plot_decision_regions(X,y,c)

# %%
ds = datasets.make_moons
