# %%
from sklearn import datasets
ds = datasets.make_classification(n_features=5)

X = ds[0][:,[0,1]]
y = ds[1]

from sklearn import svm
c = svm.SVC(kernel='rbf')

c.fit(X,y)

from plot import plot_decision_regions
# %matplotlib inline

plot_decision_regions(X,y,c)
