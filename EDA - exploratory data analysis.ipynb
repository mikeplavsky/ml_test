# %%
r = pd.read_csv("digits.csv")
x = sns.pairplot(r)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style="whitegrid", context="notebook")

cols = ["LSTAT", "INDUS","CRIM", "RM","MEDV"]
r = sns.pairplot(df[cols], size=2.0)

# %%
import numpy as np
cf = np.corrcoef(df[cols].values.T)

r = sns.heatmap(
    cf,
    cbar=True,
    annot=True,
    yticklabels=cols,
    xticklabels=cols)

# %%
import pandas as pd
df = pd.read_csv(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data",
    header=None,
    sep="\s+")

df.columns = [
"CRIM",
"ZN",
"INDUS",
"CHAS",
"NOX",
"RM",
"AGE",
"DIS",
"RAD",
"TAX",
"PTRATIO",
"B",
"LSTAT",
"MEDV"]
